# %%
getwd()
# Out:
# [1] "/fast/AG_Bunina/Yusuf/Project_Endothelial_and_Stroke/Datasets/Chromatin_and_Gene_Exp/2024_C_A_Mannens_C_et_al/04_02_25"

# %%
.libPaths()
# Out:
# [1] "/fast/home/y/ykazci/R/x86_64-unknown-linux-gnu-library/4.3"
# [2] "/gnu/store/asn7yfxccx9hqi4afrnw685xw6c6382z-profile/site-library"
# [3] "/gnu/store/29x2k7i71g9xq09xmbj1lk515cl7if63-r-minimal-4.4.2/lib/R/library"

# %%
# load the R environment with the necessary packages:

renv::load()
# Out:
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# ...

# %%
renv::status()
# Out:
# The following package(s) are in an inconsistent state:
#
#  package            installed recorded used
#  AnnotationFilter   y         n        y
#  BPCells            n         n        y
#  EnsDb.Hsapiens.v86 y         n        y
#  GenomicFeatures    y         n        y
#  JASPAR2020         n         n        y
#  ProtGenerics       y         n        y
#  ensembldb          y         n        y
#
# See ?renv::status() for advice on resolving these issues.

# %%
.libPaths()
# Out:
# [1] "/fast/AG_Bunina/Yusuf/Project_Endothelial_and_Stroke/Datasets/Chromatin_and_Gene_Exp/2024_C_A_Mannens_C_et_al/04_02_25/renv/library/linux-rhel-9.4/R-4.4/x86_64-unknown-linux-gnu"
# [2] "/fast/home/y/ykazci/.cache/R/renv/sandbox/linux-rhel-9.4/R-4.4/x86_64-unknown-linux-gnu/233218af"

# %%
another_seurat_signac_lib <- "/home/ykazci/.guix-extra-profiles/seurat_signac/seurat_signac_env/site-library"

# %%
library(magrittr)

# %%
my_seurat_signac_lib %>% list.files() %>% sort()
# Out:
#  [1] "BH"                   "Biobase"              "BiocGenerics"
#  [4] "BiocNeighbors"        "BiocParallel"         "DelayedArray"
#  [7] "GenomeInfoDb"         "GenomeInfoDbData"     "GenomicRanges"
# [10] "IRanges"              "Matrix"               "MatrixGenerics"
# [13] "R6"                   "Rcpp"                 "S4Arrays"
# [16] "S4Vectors"            "SingleCellExperiment" "SparseArray"
# [19] "SummarizedExperiment" "UCSC.utils"           "UCell"
# [22] "XVector"              "abind"                "askpass"
# [25] "assorthead"           "codetools"            "cpp11"
# [28] "crayon"               "curl"                 "data.table"
# [31] "formatR"              "futile.logger"        "futile.options"
# [34] "httr"                 "jsonlite"             "lambda.r"
# [37] "lattice"              "matrixStats"          "mime"
# [40] "openssl"              "snow"                 "sys"
# [43] "zlibbioc"

# %%
renv::hydrate(packages = 'UCell', sources = another_seurat_signac_lib)
# Out:
# The following packages were discovered:
#
# # ~/.guix-extra-profiles/seurat_signac/seurat_signac_env/site-library --------
# - UCell        2.10.1
# - assorthead   1.0.0
#
# They will be linked into the project library.
#
# The following packages are used in this project, but not available locally:
# - BiocManager
# - BiocVersion
# - grDevices
# - graphics
# - grid
# - methods
# - parallel
# - stats
# - stats4
# - tools
# - utils
# renv will attempt to download and install these packages.
#
# Done!king packages into the project library ...
# - Hydrated 2 packages in 0.23 seconds.
# - Resolving missing dependencies ...
# # Installing packages --------------------------------------------------------
# - Installing BiocManager ...                    OK [linked from cache]
# - Installing BiocVersion ...                    OK [linked from cache]

# %%
.libPaths()
# Out:
# [1] "/fast/AG_Bunina/Yusuf/Project_Endothelial_and_Stroke/Datasets/Chromatin_and_Gene_Exp/2024_C_A_Mannens_C_et_al/04_02_25/renv/library/linux-rhel-9.4/R-4.4/x86_64-unknown-linux-gnu"
# [2] "/fast/home/y/ykazci/.cache/R/renv/sandbox/linux-rhel-9.4/R-4.4/x86_64-unknown-linux-gnu/233218af"

# %%
renv::status()
# Out:
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# ...

# %%
renv::snapshot(force = TRUE)
# Out:
# The following required packages are not installed:
# - BPCells
# - JASPAR2020
# Packages must first be installed before renv can snapshot them.
# Use `renv::dependencies()` to see where this package is used in your project.
#
# The following Bioconductor packages appear to be from a separate Bioconductor release:
# - Rgraphviz         [installed 2.50.0 != latest 2.48.0]
# - SPIA              [installed 2.58.0 != latest 2.56.0]
# - KEGGgraph         [installed 1.66.0 != latest 1.64.0]
# - pathview          [installed 1.46.0 != latest 1.44.0]
# - EnrichmentBrowser [installed 2.36.0 != latest 2.34.1]
# renv may be unable to restore these packages.
# Bioconductor version: 3.19
#
# The following package(s) will be updated in the lockfile:
#
# # Bioconductor ---------------------------------------------------------------
# - EnsDb.Hsapiens.v86   [* -> 2.99.0]
#
# # Bioconductor 3.19 ----------------------------------------------------------
# - AnnotationFilter     [* -> 1.28.0]
# ...

# %%
library(UCell)

# %%
renv::status()
# Out:
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# ...

# %%
renv::snapshot(force = TRUE)
# Out:
# The following required packages are not installed:
# - BPCells
# - JASPAR2020
# Packages must first be installed before renv can snapshot them.
# Use `renv::dependencies()` to see where this package is used in your project.
#
# The following Bioconductor packages appear to be from a separate Bioconductor release:
# - Rgraphviz         [installed 2.50.0 != latest 2.48.0]
# - SPIA              [installed 2.58.0 != latest 2.56.0]
# - KEGGgraph         [installed 1.66.0 != latest 1.64.0]
# - UCell             [installed 2.10.1 != latest 2.8.0]
# - pathview          [installed 1.46.0 != latest 1.44.0]
# - EnrichmentBrowser [installed 2.36.0 != latest 2.34.1]
# renv may be unable to restore these packages.
# Bioconductor version: 3.19
#
# The following package(s) will be updated in the lockfile:
#
# # Bioconductor 3.20 ----------------------------------------------------------
# - UCell   [* -> 2.10.1]
#
# ...

# %%
sessionInfo()
# Out:
# R version 4.4.2 (2024-10-31)
# Platform: x86_64-unknown-linux-gnu
# Running under: Red Hat Enterprise Linux 9.4 (Plow)
#
# Matrix products: default
# BLAS/LAPACK: /gnu/store/mj1kw87qd3m1q7r4844adkn5hifx8k6a-openblas-0.3.20/lib/libopenblasp-r0.3.20.so;  LAPACK version 3.9.0
#
# locale:
#  [1] LC_CTYPE=C          LC_NUMERIC=C        LC_TIME=C
#  [4] LC_COLLATE=C        LC_MONETARY=C       LC_MESSAGES=C.UTF-8
#  [7] LC_PAPER=C          LC_NAME=C           LC_ADDRESS=C
# [10] LC_TELEPHONE=C      LC_MEASUREMENT=C    LC_IDENTIFICATION=C
#
# time zone: Europe/Berlin
# tzcode source: system (glibc)
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] UCell_2.10.1   magick_2.8.5   magrittr_2.0.3
#
# loaded via a namespace (and not attached):
#  [1] Matrix_1.7-0                jsonlite_1.8.8
#  [3] compiler_4.4.2              BiocManager_1.30.25
#  [5] renv_1.0.7                  crayon_1.5.3
# ...

# %%
# Add scGate package:

# %%
getwd()
# Out:
# [1] "/fast/AG_Bunina/Yusuf/Project_Endothelial_and_Stroke/Datasets/Chromatin_and_Gene_Exp/2024_C_A_Mannens_C_et_al/04_02_25"

# %%
.libPaths()
# Out:
# [1] "/fast/home/y/ykazci/R/x86_64-unknown-linux-gnu-library/4.3"
# [2] "/gnu/store/asn7yfxccx9hqi4afrnw685xw6c6382z-profile/site-library"
# [3] "/gnu/store/29x2k7i71g9xq09xmbj1lk515cl7if63-r-minimal-4.4.2/lib/R/library"

# %%
# load the R environment with the necessary packages:

renv::load()
# Out:
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# ...

# %%
renv::status()
# Out:
# The following package(s) are used in this project, but are not installed:
# - BPCells
# - JASPAR2020
#
# See ?renv::status() for advice on resolving these issues.

# %%
.libPaths()
# Out:
# [1] "/fast/AG_Bunina/Yusuf/Project_Endothelial_and_Stroke/Datasets/Chromatin_and_Gene_Exp/2024_C_A_Mannens_C_et_al/04_02_25/renv/library/linux-rhel-9.4/R-4.4/x86_64-unknown-linux-gnu"
# [2] "/fast/home/y/ykazci/.cache/R/renv/sandbox/linux-rhel-9.4/R-4.4/x86_64-unknown-linux-gnu/233218af"

# %%
another_seurat_signac_lib <- "/home/ykazci/.guix-extra-profiles/seurat_signac/seurat_signac_env/site-library"

# %%
library(magrittr)

# %%
another_seurat_signac_lib %>% list.files() %>% gtools::mixedsort()
# Out:
#   [1] "abind"                "askpass"              "assorthead"
#   [4] "base64enc"            "BH"                   "Biobase"
#   [7] "BiocGenerics"         "BiocNeighbors"        "BiocParallel"
#  [10] "bitops"               "bslib"                "cachem"
#  [13] "caTools"              "cli"                  "cluster"
#  [16] "codetools"            "colorspace"           "commonmark"
#  [19] "cowplot"              "cpp11"                "crayon"
#  [22] "crosstalk"            "curl"                 "data.table"
#  [25] "DelayedArray"         "deldir"               "digest"
#  [28] "dotCall64"            "dplyr"                "dqrng"
#  [31] "ellipsis"             "evaluate"             "fansi"
#  [34] "farver"               "fastDummies"          "fastmap"
#  [37] "fitdistrplus"         "FNN"                  "fontawesome"
#  [40] "formatR"              "fs"                   "futile.logger"
#  [43] "futile.options"       "future"               "future.apply"
# ...

# %%
renv::hydrate(packages = 'scGate', sources = another_seurat_signac_lib)
# Out:
# The following packages were discovered:
#
# # ~/.guix-extra-profiles/seurat_signac/seurat_signac_env/site-library --------
# - scGate   1.6.2
#
# They will be linked into the project library.
#
# The following packages are used in this project, but not available locally:
# - BiocManager
# - BiocVersion
# - grDevices
# - graphics
# - grid
# - methods
# - parallel
# - splines
# - stats
# - stats4
# - tools
# - utils
# renv will attempt to download and install these packages.
#
# Done!king packages into the project library ...
# - Hydrated 1 packages in 0.11 seconds.
# - Resolving missing dependencies ...
# # Installing packages --------------------------------------------------------
# - Installing BiocManager ...                    OK [linked from cache]
# - Installing BiocVersion ...                    OK [linked from cache]

# %%
renv::status()
# Out:
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# ...

# %%
library(scGate)

# %%
renv::snapshot(force = TRUE)
# Out:
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# ...

# %%
sessionInfo()
# Out:
# R version 4.4.2 (2024-10-31)
# Platform: x86_64-unknown-linux-gnu
# Running under: Red Hat Enterprise Linux 9.4 (Plow)
#
# Matrix products: default
# BLAS/LAPACK: /gnu/store/mj1kw87qd3m1q7r4844adkn5hifx8k6a-openblas-0.3.20/lib/libopenblasp-r0.3.20.so;  LAPACK version 3.9.0
#
# locale:
#  [1] LC_CTYPE=C          LC_NUMERIC=C        LC_TIME=C
#  [4] LC_COLLATE=C        LC_MONETARY=C       LC_MESSAGES=C.UTF-8
#  [7] LC_PAPER=C          LC_NAME=C           LC_ADDRESS=C
# [10] LC_TELEPHONE=C      LC_MEASUREMENT=C    LC_IDENTIFICATION=C
#
# time zone: Europe/Berlin
# tzcode source: system (glibc)
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] scGate_1.6.2   magrittr_2.0.3
#
# loaded via a namespace (and not attached):
#   [1] RColorBrewer_1.1-3          UCell_2.10.1
#   [3] jsonlite_1.8.8              spatstat.utils_3.1-2
#   [5] farver_2.1.2                vctrs_0.6.5
# ...

# %%
# Add philentropy package:

# %%
getwd()
# Out:
# [1] "/fast/AG_Bunina/Yusuf/Project_Endothelial_and_Stroke/Datasets/Chromatin_and_Gene_Exp/2024_C_A_Mannens_C_et_al/04_02_25"

# %%
.libPaths()
# Out:
# [1] "/fast/home/y/ykazci/R/x86_64-unknown-linux-gnu-library/4.3"
# [2] "/gnu/store/asn7yfxccx9hqi4afrnw685xw6c6382z-profile/site-library"
# [3] "/gnu/store/29x2k7i71g9xq09xmbj1lk515cl7if63-r-minimal-4.4.2/lib/R/library"

# %%
# load the R environment with the necessary packages:

renv::load()
# Out:
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# ...

# %%
# ignore below:

renv::status()
# Out:
# The following package(s) are in an inconsistent state:
#
#  package      installed recorded used
#  BPCells      n         n        y
#  GRaNPA       y         n        y
#  JASPAR2020   n         n        y
#  ModelMetrics y         n        y
#  SQUAREM      y         n        y
#  caret        y         n        y
#  class        y         n        y
#  clock        y         n        y
#  diagram      y         n        y
#  e1071        y         n        y
#  ggprism      y         n        y
#  gower        y         n        y
#  hardhat      y         n        y
#  ipred        y         n        y
#  lava         y         n        y
#  pROC         y         n        y
#  paletteer    y         n        y
#  prismatic    y         n        y
#  prodlim      y         n        y
#  proxy        y         n        y
#  ranger       y         n        y
#  recipes      y         n        y
#  rpart        y         n        y
#  scCustomize  y         n        y
# ...

# %%
.libPaths()
# Out:
# [1] "/fast/AG_Bunina/Yusuf/Project_Endothelial_and_Stroke/Datasets/Chromatin_and_Gene_Exp/2024_C_A_Mannens_C_et_al/04_02_25/renv/library/linux-rhel-9.4/R-4.4/x86_64-unknown-linux-gnu"
# [2] "/fast/home/y/ykazci/.cache/R/renv/sandbox/linux-rhel-9.4/R-4.4/x86_64-unknown-linux-gnu/233218af"

# %%
another_seurat_signac_lib <- "/home/ykazci/.guix-extra-profiles/seurat_signac/seurat_signac_env/site-library"

# %%
library(magrittr)

# %%
another_seurat_signac_lib %>% list.files() %>% gtools::mixedsort()
# Out:
#   [1] "abind"                "askpass"              "assorthead"
#   [4] "base64enc"            "BH"                   "Biobase"
#   [7] "BiocGenerics"         "BiocNeighbors"        "BiocParallel"
#  [10] "bitops"               "bslib"                "cachem"
#  [13] "caTools"              "cli"                  "cluster"
#  [16] "codetools"            "colorspace"           "commonmark"
#  [19] "cowplot"              "cpp11"                "crayon"
#  [22] "crosstalk"            "curl"                 "data.table"
#  [25] "DelayedArray"         "deldir"               "digest"
#  [28] "dotCall64"            "dplyr"                "dqrng"
#  [31] "ellipsis"             "evaluate"             "fansi"
#  [34] "farver"               "fastDummies"          "fastmap"
#  [37] "fitdistrplus"         "FNN"                  "fontawesome"
#  [40] "formatR"              "fs"                   "futile.logger"
#  [43] "futile.options"       "future"               "future.apply"
# ...

# %%
renv::hydrate(packages = 'philentropy', sources = another_seurat_signac_lib)
# Out:
# The following packages were discovered:
#
# # ~/.guix-extra-profiles/seurat_signac/seurat_signac_env/site-library --------
# - philentropy   0.9.0
# - poorman       0.2.7
#
# They will be linked into the project library.
#
# The following packages are used in this project, but not available locally:
# - methods
# - stats
# - utils
# renv will attempt to download and install these packages.
#
# Done!king packages into the project library ...
# - Hydrated 2 packages in 1.1 seconds.
# - Resolving missing dependencies ...
# # Installing packages --------------------------------------------------------

# %%
renv::status()
# Out:
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# ...

# %%
library(philentropy)

# %%
renv::snapshot(force = TRUE)
# Out:
# The following required packages are not installed:
# - BPCells
# - JASPAR2020
# Packages must first be installed before renv can snapshot them.
# Use `renv::dependencies()` to see where this package is used in your project.
#
# The following Bioconductor packages appear to be from a separate Bioconductor release:
# - SPIA              [installed 2.58.0 != latest 2.56.0]
# - Rgraphviz         [installed 2.50.0 != latest 2.48.0]
# - KEGGgraph         [installed 1.66.0 != latest 1.64.0]
# - UCell             [installed 2.10.1 != latest 2.8.0]
# - pathview          [installed 1.46.0 != latest 1.44.0]
# - EnrichmentBrowser [installed 2.36.0 != latest 2.34.1]
# renv may be unable to restore these packages.
# Bioconductor version: 3.19
#
# The following package(s) will be updated in the lockfile:
#
# # CRAN -----------------------------------------------------------------------
# - ModelMetrics   [* -> 1.2.2.2]
# - SQUAREM        [* -> 2021.1]
# - caret          [* -> 6.0-94]
# ...

# %%
# wait a bit for the newly installed package to get detected:

# %%
renv::status()
# Out:
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# Warning message in Sys.setlocale():
# "OS reports request to set locale to "" cannot be honored"
# ...

# %%
renv::snapshot(force = TRUE)
# Out:
# The following required packages are not installed:
# - BPCells
# - JASPAR2020
# Packages must first be installed before renv can snapshot them.
# Use `renv::dependencies()` to see where this package is used in your project.
#
# The following Bioconductor packages appear to be from a separate Bioconductor release:
# - SPIA              [installed 2.58.0 != latest 2.56.0]
# - Rgraphviz         [installed 2.50.0 != latest 2.48.0]
# - KEGGgraph         [installed 1.66.0 != latest 1.64.0]
# - UCell             [installed 2.10.1 != latest 2.8.0]
# - pathview          [installed 1.46.0 != latest 1.44.0]
# - EnrichmentBrowser [installed 2.36.0 != latest 2.34.1]
# renv may be unable to restore these packages.
# Bioconductor version: 3.19
#
# The following package(s) will be updated in the lockfile:
#
# # CRAN -----------------------------------------------------------------------
# - philentropy   [* -> 0.9.0]
# - poorman       [* -> 0.2.7]
#
# ...

# %%
sessionInfo()
# Out:
# R version 4.4.2 (2024-10-31)
# Platform: x86_64-unknown-linux-gnu
# Running under: Red Hat Enterprise Linux 9.4 (Plow)
#
# Matrix products: default
# BLAS/LAPACK: /gnu/store/mj1kw87qd3m1q7r4844adkn5hifx8k6a-openblas-0.3.20/lib/libopenblasp-r0.3.20.so;  LAPACK version 3.9.0
#
# locale:
#  [1] LC_CTYPE=C          LC_NUMERIC=C        LC_TIME=C
#  [4] LC_COLLATE=C        LC_MONETARY=C       LC_MESSAGES=C.UTF-8
#  [7] LC_PAPER=C          LC_NAME=C           LC_ADDRESS=C
# [10] LC_TELEPHONE=C      LC_MEASUREMENT=C    LC_IDENTIFICATION=C
#
# time zone: Europe/Berlin
# tzcode source: system (glibc)
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] philentropy_0.9.0 magrittr_2.0.3
#
# loaded via a namespace (and not attached):
#  [1] digest_0.6.37       IRdisplay_1.1       utf8_1.2.4
#  [4] base64enc_0.1-3     fastmap_1.2.0       gtools_3.9.5
#  [7] glue_1.7.0          htmltools_0.5.8.1   repr_1.1.7
# ...
