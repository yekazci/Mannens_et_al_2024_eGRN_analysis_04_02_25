# %% [markdown]
# In this notebook, I will activate my renv environment for the previous \
# project folder in which Mannens et al. 2024 data was analyzed.\
#
# I copied renv folder and renv.lock file from the other project folder.\
# Since I did not copy any script, renv::status() will give some warning \
# about some unused packages. It is normal.

# %%
getwd()
# Out:
# [1] "/fast/AG_Bunina/Yusuf/Project_Endothelial_and_Stroke/Datasets/Chromatin_and_Gene_Exp/2024_C_A_Mannens_C_et_al/04_02_25"

# %%
.libPaths()
# Out:
# [1] "/fast/home/y/ykazci/R/x86_64-unknown-linux-gnu-library/4.3"
# [2] "/gnu/store/rm46swxwc4dgpqxp8cmbhbln1glrzvff-profile/site-library"
# [3] "/gnu/store/4qhvxbif4dz0lpmyyj884c0f8rf5n4kv-r-minimal-4.4.1/lib/R/library"

# %%
renv::load()
# Out:
# - The project is out-of-sync -- use `renv::status()` for details.

# %%
renv::status()
# Out:
# The following package(s) are in an inconsistent state:
#
#  package                     installed recorded used
#  abind                       y         y        n
#  annotate                    y         y        n
#  AnnotationDbi               y         y        n
#  AnnotationFilter            y         y        n
#  ape                         y         y        n
#  aplot                       y         y        n
#  askpass                     y         y        n
#  babelgene                   y         y        n
#  backports                   y         y        n
#  base64enc                   y         y        n
#  bayestestR                  y         y        n
#  beachmat                    y         y        n
#  beeswarm                    y         y        n
#  BH                          y         y        n
#  Biobase                     y         y        n
#  BiocGenerics                y         y        n
#  BiocIO                      y         y        n
# ...

# %%
# Everything is OK. I did not use any package yet in a script so it warns.

# %%
.libPaths()
# Out:
# [1] "/fast/AG_Bunina/Yusuf/Project_Endothelial_and_Stroke/Datasets/Chromatin_and_Gene_Exp/2024_C_A_Mannens_C_et_al/04_02_25/renv/library/linux-rhel-9.4/R-4.4/x86_64-unknown-linux-gnu"
# [2] "/fast/home/y/ykazci/.cache/R/renv/sandbox/linux-rhel-9.4/R-4.4/x86_64-unknown-linux-gnu/694a7db3"

# %%
# install Ellmer package to use LLM models:

renv::install(packages = 'ellmer')
# Out:
# # Downloading packages -------------------------------------------------------
# - Downloading ellmer from CRAN ...              OK [652 Kb in 0.46s]
# - Downloading coro from CRAN ...                OK [61 Kb in 0.25s]
# - Downloading httr2 from CRAN ...               OK [247.4 Kb in 0.28s]
# - Downloading curl from CRAN ...                OK [911.3 Kb in 0.41s]
# - Downloading later from CRAN ...               OK [68.2 Kb in 0.23s]
# - Downloading promises from CRAN ...            OK [3 Mb in 0.38s]
# - Downloading S7 from CRAN ...                  OK [178.9 Kb in 0.28s]
# Successfully downloaded 7 packages in 3.4 seconds.
#
# The following package(s) will be installed:
# - coro     [1.1.0]
# - curl     [6.2.0]
# - ellmer   [0.1.0]
# - httr2    [1.1.0]
# - later    [1.4.1]
# - promises [1.3.2]
# - S7       [0.2.0]
# ...

# %%
renv::status()
# Out:
# The following package(s) are in an inconsistent state:
#
#  package                     installed recorded used
#  abind                       y         y        n
#  annotate                    y         y        n
#  AnnotationDbi               y         y        n
#  AnnotationFilter            y         y        n
#  ape                         y         y        n
#  aplot                       y         y        n
#  askpass                     y         y        n
#  babelgene                   y         y        n
#  backports                   y         y        n
#  bayestestR                  y         y        n
#  beachmat                    y         y        n
#  beeswarm                    y         y        n
#  BH                          y         y        n
#  Biobase                     y         y        n
#  BiocGenerics                y         y        n
#  BiocIO                      y         y        n
#  BiocManager                 y         y        n
# ...

# %%
renv::snapshot()
# Out:
# The following package(s) will be updated in the lockfile:
#
# # Bioconductor ---------------------------------------------------------------
# - BSgenome.Hsapiens.UCSC.hg19   [1.4.3 -> *]
# - BSgenome.Hsapiens.UCSC.hg38   [1.4.5 -> *]
# - EnsDb.Hsapiens.v86            [2.99.0 -> *]
# - GenomeInfoDbData              [1.2.12 -> *]
# - GO.db                         [3.19.1 -> *]
#
# # Bioconductor 3.19 ----------------------------------------------------------
# - annotate                      [1.82.0 -> *]
# - AnnotationDbi                 [1.66.0 -> *]
# - AnnotationFilter              [1.28.0 -> *]
# - beachmat                      [2.20.0 -> *]
# - Biobase                       [2.64.0 -> *]
# - BiocGenerics                  [0.50.0 -> *]
# - BiocIO                        [1.14.0 -> *]
# - BiocParallel                  [1.38.0 -> *]
# - BiocSingular                  [1.20.0 -> *]
# - BiocVersion                   [3.19.1 -> *]
# - Biostrings                    [2.72.1 -> *]
# ...

# %%
library(ellmer)

# %%
renv::status()
# Out:
# No issues found -- the project is in a consistent state.

# %%
renv::snapshot()
# Out:
# The following package(s) will be updated in the lockfile:
#
# # CRAN -----------------------------------------------------------------------
# - askpass    [* -> 1.2.0]
# - coro       [* -> 1.1.0]
# - curl       [* -> 6.2.0]
# - ellmer     [* -> 0.1.0]
# - httr2      [* -> 1.1.0]
# - later      [* -> 1.4.1]
# - magrittr   [* -> 2.0.3]
# - openssl    [* -> 2.2.1]
# - promises   [* -> 1.3.2]
# - R6         [* -> 2.5.1]
# - rappdirs   [* -> 0.3.3]
# - Rcpp       [* -> 1.0.13]
# - S7         [* -> 0.2.0]
# - sys        [* -> 3.4.2]
# - withr      [* -> 3.0.1]
#
# - Lockfile written to "/fast/AG_Bunina/Yusuf/Project_Endothelial_and_Stroke/Datasets/Chromatin_and_Gene_Exp/2024_C_A_Mannens_C_et_al/04_02_25/renv.lock".

# %%
renv::status()
# Out:
# No issues found -- the project is in a consistent state.

# %%
renv::snapshot()
# Out:
# - The lockfile is already up to date.

# %%
sessionInfo()
# Out:
# R version 4.4.1 (2024-06-14)
# Platform: x86_64-unknown-linux-gnu
# Running under: Red Hat Enterprise Linux 9.4 (Plow)
#
# Matrix products: default
# BLAS/LAPACK: /gnu/store/mvbj21lcf387dgs04d29n0sxrydq03a6-openblas-0.3.20/lib/libopenblasp-r0.3.20.so;  LAPACK version 3.9.0
#
# locale:
#  [1] LC_CTYPE=en_GB.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_GB.UTF-8        LC_COLLATE=en_GB.UTF-8
#  [5] LC_MONETARY=en_GB.UTF-8    LC_MESSAGES=en_GB.UTF-8
#  [7] LC_PAPER=en_GB.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_GB.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Europe/Berlin
# tzcode source: system (glibc)
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] ellmer_0.1.0
#
# loaded via a namespace (and not attached):
#  [1] crayon_1.5.3        vctrs_0.6.5         cli_3.6.3
#  [4] rlang_1.1.4         renv_1.0.7          S7_0.2.0
# ...
