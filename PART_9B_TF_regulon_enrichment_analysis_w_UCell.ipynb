# %%
getwd()
# Out:
# [1] "/fast/AG_Bunina/Yusuf/Project_Endothelial_and_Stroke/Datasets/Chromatin_and_Gene_Exp/2024_C_A_Mannens_C_et_al/04_02_25"

# %%
.libPaths()
# Out:
# [1] "/fast/home/y/ykazci/R/x86_64-unknown-linux-gnu-library/4.3"
# [2] "/gnu/store/asn7yfxccx9hqi4afrnw685xw6c6382z-profile/site-library"
# [3] "/gnu/store/29x2k7i71g9xq09xmbj1lk515cl7if63-r-minimal-4.4.2/lib/R/library"

# %%
here::here()
# Out:
# [1] "/fast/AG_Bunina/Yusuf/Project_Endothelial_and_Stroke/Datasets/Chromatin_and_Gene_Exp/2024_C_A_Mannens_C_et_al/04_02_25"

# %%
my_seurat_signac_lib <- "/fast/AG_Bunina/Yusuf/Project_Endothelial_and_Stroke/renv_envs/seurat_signac/renv/library/linux-rhel-9.4/R-4.4/x86_64-unknown-linux-gnu"

my_epiregulon_lib <- "/fast/AG_Bunina/Yusuf/Project_Endothelial_and_Stroke/Datasets/Chromatin_and_Gene_Exp/2024_C_A_Mannens_C_et_al/04_02_25/renv/library/linux-rhel-9.4/R-4.4/x86_64-unknown-linux-gnu"

my_bpcells_lib <- "/fast/AG_Bunina/Yusuf/Project_Endothelial_and_Stroke/renv_envs/BPCELLS/renv/library/linux-rhel-9.4/R-4.4/x86_64-unknown-linux-gnu"

my_ArchR_lib <- "/fast/AG_Bunina/Yusuf/Project_Endothelial_and_Stroke/renv_envs/ARCHR/renv/library/linux-rhel-9.4/R-4.4/x86_64-unknown-linux-gnu"

my_seurat_extend_scCustomize_lib  <- 
    "/fast/AG_Bunina/Yusuf/Project_Endothelial_and_Stroke/renv_envs/seuratExtend_scCustomize/renv/library/linux-rhel-9.4/R-4.4/x86_64-unknown-linux-gnu"

# %%
library(magrittr)

# %%
my_seurat_signac_lib %>% list.files() %>% sort()
# Out:
#   [1] "AnnotationDbi"        "AnnotationFilter"     "BH"
#   [4] "Biobase"              "BiocGenerics"         "BiocIO"
#   [7] "BiocManager"          "BiocParallel"         "BiocVersion"
#  [10] "Biostrings"           "DBI"                  "DelayedArray"
#  [13] "EnsDb.Hsapiens.v86"   "FNN"                  "GenomeInfoDb"
#  [16] "GenomeInfoDbData"     "GenomicAlignments"    "GenomicFeatures"
#  [19] "GenomicRanges"        "IRanges"              "IRdisplay"
#  [22] "IRkernel"             "KEGGREST"             "KernSmooth"
#  [25] "MASS"                 "Matrix"               "MatrixGenerics"
#  [28] "ProtGenerics"         "R6"                   "RANN"
#  [31] "RColorBrewer"         "RCurl"                "ROCR"
#  [34] "RSQLite"              "RSpectra"             "Rcpp"
#  [37] "RcppAnnoy"            "RcppArmadillo"        "RcppEigen"
#  [40] "RcppHNSW"             "RcppProgress"         "RcppRoll"
#  [43] "RcppTOML"             "Rhtslib"              "Rsamtools"
# ...

# %%
my_epiregulon_lib %>% list.files() %>% sort()
# Out:
#   [1] "AUCell"                       "AnnotationDbi"
#   [3] "AnnotationFilter"             "AnnotationHub"
#   [5] "AzureAuth"                    "AzureGraph"
#   [7] "AzureRMR"                     "AzureStor"
#   [9] "BH"                           "BSgenome"
#  [11] "BSgenome.Hsapiens.UCSC.hg19"  "BSgenome.Hsapiens.UCSC.hg38"
#  [13] "BSgenome.Mmusculus.UCSC.mm10" "Biobase"
#  [15] "BiocBaseUtils"                "BiocFileCache"
#  [17] "BiocGenerics"                 "BiocIO"
#  [19] "BiocManager"                  "BiocNeighbors"
#  [21] "BiocParallel"                 "BiocSingular"
#  [23] "BiocVersion"                  "Biostrings"
#  [25] "BuenColors"                   "CNEr"
#  [27] "Cairo"                        "ComplexHeatmap"
#  [29] "DBI"                          "DOSE"
#  [31] "DT"                           "DelayedArray"
#  [33] "DelayedMatrixStats"           "Deriv"
#  [35] "DirichletMultinomial"         "EnrichmentBrowser"
# ...

# %%
my_seurat_extend_scCustomize_lib %>% list.files() %>% sort()
# Out:
#   [1] "AnnotationDbi"        "AnnotationFilter"     "AnnotationHub"
#   [4] "BH"                   "Biobase"              "BiocFileCache"
#   [7] "BiocGenerics"         "BiocIO"               "BiocManager"
#  [10] "BiocNeighbors"        "BiocParallel"         "BiocSingular"
#  [13] "BiocVersion"          "Biostrings"           "Cairo"
#  [16] "DBI"                  "DelayedArray"         "DelayedMatrixStats"
#  [19] "Deriv"                "FNN"                  "Formula"
#  [22] "GenomeInfoDb"         "GenomeInfoDbData"     "GenomicAlignments"
#  [25] "GenomicFeatures"      "GenomicRanges"        "GlobalOptions"
#  [28] "IRanges"              "IRdisplay"            "IRkernel"
#  [31] "KEGGREST"             "KernSmooth"           "MASS"
#  [34] "Matrix"               "MatrixGenerics"       "MatrixModels"
#  [37] "ProtGenerics"         "R6"                   "RANN"
#  [40] "RColorBrewer"         "RCurl"                "ROCR"
#  [43] "RSQLite"              "RSpectra"             "Rcpp"
# ...

# %%
my_ArchR_lib %>% list.files() %>% sort()
# Out:
#   [1] "AnnotationDbi"               "ArchR"
#   [3] "BH"                          "BSgenome"
#   [5] "BSgenome.Hsapiens.UCSC.hg19" "Biobase"
#   [7] "BiocGenerics"                "BiocIO"
#   [9] "BiocManager"                 "BiocParallel"
#  [11] "BiocVersion"                 "Biostrings"
#  [13] "CNEr"                        "Cairo"
#  [15] "ComplexHeatmap"              "DBI"
#  [17] "DESeq2"                      "DT"
#  [19] "DelayedArray"                "DirichletMultinomial"
#  [21] "FNN"                         "GO.db"
#  [23] "GenomeInfoDb"                "GenomeInfoDbData"
#  [25] "GenomicAlignments"           "GenomicRanges"
#  [27] "GetoptLong"                  "GlobalOptions"
#  [29] "IRanges"                     "KEGGREST"
#  [31] "KernSmooth"                  "MASS"
#  [33] "Matrix"                      "MatrixGenerics"
#  [35] "R.methodsS3"                 "R.oo"
#  [37] "R.utils"                     "R6"
#  [39] "RANN"                        "RColorBrewer"
# ...

# %%
my_bpcells_lib %>% list.files() %>% sort()
# Out:
#   [1] "AnnotationDbi"               "BH"
#   [3] "BPCells"                     "BSgenome"
#   [5] "BSgenome.Hsapiens.UCSC.hg38" "Biobase"
#   [7] "BiocGenerics"                "BiocIO"
#   [9] "BiocManager"                 "BiocParallel"
#  [11] "BiocVersion"                 "Biostrings"
#  [13] "CNEr"                        "DBI"
#  [15] "DelayedArray"                "DirichletMultinomial"
#  [17] "FNN"                         "GO.db"
#  [19] "GenomeInfoDb"                "GenomeInfoDbData"
#  [21] "GenomicAlignments"           "GenomicRanges"
#  [23] "IRanges"                     "KEGGREST"
#  [25] "MASS"                        "Matrix"
#  [27] "MatrixGenerics"              "R.methodsS3"
#  [29] "R.oo"                        "R.utils"
#  [31] "R6"                          "RColorBrewer"
#  [33] "RCurl"                       "RSQLite"
#  [35] "RSpectra"                    "Rcpp"
#  [37] "RcppAnnoy"                   "RcppArmadillo"
#  [39] "RcppEigen"                   "RcppHNSW"
# ...

# %%
# Installed UCell package:

my_epiregulon_lib %>% list.files() %>% gtools::mixedsort()
# Out:
#   [1] "abind"                        "annotate"
#   [3] "AnnotationDbi"                "AnnotationFilter"
#   [5] "AnnotationHub"                "ape"
#   [7] "aplot"                        "askpass"
#   [9] "assorthead"                   "AUCell"
#  [11] "AzureAuth"                    "AzureGraph"
#  [13] "AzureRMR"                     "AzureStor"
#  [15] "babelgene"                    "backports"
#  [17] "base64enc"                    "bayestestR"
#  [19] "beachmat"                     "beeswarm"
#  [21] "BH"                           "Biobase"
#  [23] "BiocBaseUtils"                "BiocFileCache"
#  [25] "BiocGenerics"                 "BiocIO"
#  [27] "BiocManager"                  "BiocNeighbors"
#  [29] "BiocParallel"                 "BiocSingular"
#  [31] "BiocVersion"                  "Biostrings"
#  [33] "bit64"                        "bit"
#  [35] "bitops"                       "blob"
#  [37] "bluster"                      "boot"
# ...

# %%
.libPaths(new = my_epiregulon_lib, include.site = FALSE)

# %%
.libPaths()
# Out:
# [1] "/fast/AG_Bunina/Yusuf/Project_Endothelial_and_Stroke/Datasets/Chromatin_and_Gene_Exp/2024_C_A_Mannens_C_et_al/04_02_25/renv/library/linux-rhel-9.4/R-4.4/x86_64-unknown-linux-gnu"
# [2] "/gnu/store/29x2k7i71g9xq09xmbj1lk515cl7if63-r-minimal-4.4.2/lib/R/library"

# %%
here::here('r_objects') |> list.files()
# Out:
#  [1] "GeneExpressionMatrix.RDS"
#  [2] "GeneExpressionMatrix_used_for_epiregulon.RDS"
#  [3] "PeakMatrix.RDS"
#  [4] "PeakMatrix_used_for_epiregulon.RDS"
#  [5] "TF_activity_chunks"
#  [6] "atac_qc_by_BPCells.RDS"
#  [7] "atac_read_counts_by_BPCells.RDS"
#  [8] "coef_DF_combined.RDS"
#  [9] "features_vector_combined.RDS"
# [10] "fit_DF_combined.RDS"
# [11] "mannens_et_al_seurat_modified.RDS"
# [12] "mannens_et_al_seurat_obj.RDS"
# [13] "mannens_et_al_w_JOINT_PANDO_eGRNs.RDS"
# [14] "mat_rna_norm_pseudobulk.RDS"
# [15] "metadata.RDS"
# [16] "my_human_pwms_v2.RDS"
# [17] "pando_eGRN_chunks_final"
# [18] "pca_atac_by_bpcells_package.RDS"
# [19] "pca_rna_by_bpcells_package.RDS"
# [20] "peaks_granges_for_TF_footprinting_by_BPCells.RDS"
# [21] "regulon_w_subset_by_EC.RDS"
# [22] "regulon_weighted_by_celltypes.RDS"
# [23] "sce_atac_mannens.RDS"
# [24] "sce_rna_mannens.RDS"
# [25] "tf_activity_by_all_cells_matrix_NORMALIZED.RDS"
# [26] "tf_activity_by_cells_matrix.RDS"
# ...

# %%
# import regulon data:

regulon.w_EC  <-  
    readRDS(here::here('r_objects', 'regulon_w_subset_by_EC.RDS'))

# %%
regulon.w_EC %>% head()
# Out:
#   idxATAC chr   start     end       idxRNA target  distance idxTF tf
# 1   500   chr10 102452780 102453181 2743   SUFU     50780   1030  ADNP
# 2  3296   chr10  11685819  11686220 2195   USP6NL   74152   1030  ADNP
# 3  8072   chr10  16811761  16812162 2229   RSU1      5300   1030  ADNP
# 4  8249   chr10  17578642  17579043 2233   ST8SIA6 124046   1030  ADNP
# 5  9035   chr10  22615883  22616284 2254   PIP4K2A  98293   1030  ADNP
# 6 11842   chr10   3852277   3852678 2145   KLF6     66995   1030  ADNP
#   corr_all  pval.endothelial_cells stats.endothelial_cells
# 1 0.5482681 0.8612509              0.03054877
# 2 0.5946883 0.1846988              1.75940485
# 3 0.5749533 0.7676991              0.08725281
# 4 0.7936897 0.1466853              2.10638704
# 5 0.5910475 0.4075012              0.68607907
# 6 0.5239147 0.4476775              0.57652538
#   qval.endothelial_cells weight.endothelial_cells estimate
# 1 1                      0.06412986               0.06412986
# ...

# %%
sessionInfo()
# Out:
# R version 4.4.2 (2024-10-31)
# Platform: x86_64-unknown-linux-gnu
# Running under: Red Hat Enterprise Linux 9.4 (Plow)
#
# Matrix products: default
# BLAS/LAPACK: /gnu/store/mj1kw87qd3m1q7r4844adkn5hifx8k6a-openblas-0.3.20/lib/libopenblasp-r0.3.20.so;  LAPACK version 3.9.0
#
# locale:
#  [1] LC_CTYPE=C          LC_NUMERIC=C        LC_TIME=C
#  [4] LC_COLLATE=C        LC_MONETARY=C       LC_MESSAGES=C.UTF-8
#  [7] LC_PAPER=C          LC_NAME=C           LC_ADDRESS=C
# [10] LC_TELEPHONE=C      LC_MEASUREMENT=C    LC_IDENTIFICATION=C
#
# time zone: Europe/Berlin
# tzcode source: system (glibc)
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] magrittr_2.0.3
#
# loaded via a namespace (and not attached):
#  [1] digest_0.6.37     IRdisplay_1.1     utf8_1.2.4        base64enc_0.1-3
#  [5] fastmap_1.2.0     gtools_3.9.5      glue_1.7.0        htmltools_0.5.8.1
# ...
